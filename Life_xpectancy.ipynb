# %% [markdown]
# <a href="https://colab.research.google.com/github/Rozgardiasz00/IBMCoursera/blob/main/Life_xpectancy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Podział na grupy projektowe (max. 2-3 osoby)
#
# 2. Zrozumienie i analiza problemu, który prezentują dane
#
#
# * Zapoznanie się z wybranym zestawem danych i opisem zadania do
# wykonania
#
# * Pobranie bazy danych na swój komputer
#
# * Zdefiniowanie co wiemy na dany temat
#
# * Efektem tego punktu powinien być krótki 1-2 stronicowy wstęp
# teoretyczny analizujący problem od strony biznesowej/merytorycznej
#
#
# 3. Wstępne zapoznanie się z przedstawioną bazą danych
# -replace NaNs with median
# -delete leading and taling spaces
# -dtyupes
#
# - #dummies for developed
# -correclation matrix
# -2015 Scatter plt
# -2015 box plots per Devoloped not Developed-2015 correclation matrix
# -hiv/aids
# +composition of resourses
# +audult mortality
# +infant deaths
# +thines 1-19
# +hinnes 5-9
# +schooling
#
# status binarny do box
#
#
#
#
#
#
# 4. Podsumowanie kroku 2 i 3 oraz dokładne opisanie i przedstawienie hipotez, które będą rozwiązywane
#
# * Zebranie wyników z punktu 3. i wiedzy z punktu 2.
#
# * Opis tego, co zamierzamy zrobić wykorzystując zdobyte informacje
#
# * Opis czego nie możemy zrobić na danej bazie danych z uwagi np. na brak informacji, zbyt dużo wartości odstających
#
# * Podanie kilku algorytmów/modeli uczenia maszynowego rozwiązujących problemy
# regresji, który będziemy chcieli użyć w tym projekcie
#
#
#
#
# 5. Analiza, wizualizacja danych oraz przeprowadzenie analizy statystycznej w języku Python
#
#
#
# 6. Użycie i przetestowanie różnych algorytmów regresji do analizy problemów liniowych i nieliniowych
#
# -regresja liniowa
#
# -regresja wielu zmiennych
#
# >  gradient prosty (z pre-normalizają min-max)
#
#
#
# -regresja wielomianowa?
#
# 7. Ocena działania algorytmu
#
# -decisiion tree
#
#
# 8. Wyjaśnienie dlaczego użyty został akurat ten algorytm
#
# 9. Propozycja jego użycia

# %% [markdown]
# #Wstęp

# %% [markdown]
# ####Context
#
# Although there have been lot of studies undertaken in the past on factors affecting life expectancy considering demographic variables, income composition and mortality rates. It was found that affect of immunization and human development index was not taken into account in the past. Also, some of the past research was done considering multiple linear regression based on data set of one year for all the countries. Hence, this gives motivation to resolve both the factors stated previously by formulating a regression model based on mixed effects model and multiple linear regression while considering data from a period of 2000 to 2015 for all the countries. Important immunization like Hepatitis B, Polio and Diphtheria will also be considered. In a nutshell, this study will focus on immunization factors, mortality factors, economic factors, social factors and other health related factors as well. Since the observations this dataset are based on different countries, it will be easier for a country to determine the predicting factor which is contributing to lower value of life expectancy. This will help in suggesting a country which area should be given importance in order to efficiently improve the life expectancy of its population.
# Content
#
# The project relies on accuracy of data. The Global Health Observatory (GHO) data repository under World Health Organization (WHO) keeps track of the health status as well as many other related factors for all countries The data-sets are made available to public for the purpose of health data analysis. The data-set related to life expectancy, health factors for 193 countries has been collected from the same WHO data repository website and its corresponding economic data was collected from United Nation website. Among all categories of health-related factors only those critical factors were chosen which are more representative. It has been observed that in the past 15 years , there has been a huge development in health sector resulting in improvement of human mortality rates especially in the developing nations in comparison to the past 30 years. Therefore, in this project we have considered data from year 2000-2015 for 193 countries for further analysis. The individual data files have been merged together into a single data-set. On initial visual inspection of the data showed some missing values. As the data-sets were from WHO, we found no evident errors. Missing data was handled in R software by using Missmap command. The result indicated that most of the missing data was for population, Hepatitis B and GDP. The missing data were from less known countries like Vanuatu, Tonga, Togo, Cabo Verde etc. Finding all data for these countries was difficult and hence, it was decided that we exclude these countries from the final model data-set. The final merged file(final dataset) consists of 22 Columns and 2938 rows which meant 20 predicting variables. All predicting variables was then divided into several broad categories:​Immunization related factors, Mortality factors, Economical factors and Social factors.
# Acknowledgements
#
# The data was collected from WHO and United Nations website with the help of Deeksha Russell and Duan Wang.

# %% [markdown]
# ###M
#
# A:2010
#
#
#
#
# Year 2010
# Devoloped Developing = dummies
#
#
#
# Examination of correlation heatmap reveals that there is a high correlation between the 2010 Life expectancy and composition of resourse, schooling, BMI and status of a country, poulation. Nagative correlation has been observed for hiv/aids, infant deaths, audult mortality, thinnes 1-19, thinnes 5-9.
#
# Regression models targeting Life Expectancy with following independent variables is established: composition of resourse, schooling, BMI and status of a country, population as well as hiv/aids, infant deaths, audult mortality, thinnes 1-19, thinnes 5-9.
#
# We aim to visualize 2010 Life Expectancy in comparison with: composition of resourse, schooling, BMI and status of a country, population as well as hiv/aids, infant deaths, audult mortality, thinnes 1-19, thinnes 5-9 variables. Scatter, box and bar type plots were utilised for respective data types.
#
#
#
#
# We are building a statistical model that incorporates following predictor variables: composition of resourse, schooling, BMI and status of a country, population as well as hiv/aids, infant deaths, audult mortality, thinnes 1-19, thinnes 5-9 variables.
#
# The aim is to investigate how these factors collectively influence the response variable, which in this case could be Life Expectancy or another relevant metric. Through this analysis, we seek to understand the combined impact of a country's Gross Domestic Product (GDP), its change in time, and its economic status on the chosen outcome variable. This model will help us explore and quantify the relationships among these variables and their collective effect on the outcome.
#
#
#
#
#
# We establish a polynomial model to examine the relationship between (###)and life expectancy. This approach allows us to capture more complex patterns in the data that a simple linear model might miss. Let's proceed with creating and fitting our polynomial model.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.3/357.3 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 7.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 20.3 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=6ffa176543b7deb1c4e599d8f8a8ff9cb1bac297237e4979dfd0255e5409970a
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
who_df = pd.read_csv("/content/Life Expectancy Data.csv")
who_df_10 = who_df[who_df['Year'] == 2010] # narrowing down to 2010
who_df_10.head()
# Out:
#                 Country  Year      Status  Life expectancy   Adult Mortality  \
# 5           Afghanistan  2010  Developing              58.8            279.0
# 21              Albania  2010  Developing              76.2             91.0
# 37              Algeria  2010  Developing              74.7            119.0
# 53               Angola  2010  Developing              49.6            365.0
# 69  Antigua and Barbuda  2010  Developing              75.6            138.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 5              74     0.01               79.679367         66.0      1989
# 21              1     5.28               41.822757         99.0        10
# 37             21     0.45              430.717586         95.0       103
# 53             78     7.80              191.653741         77.0      1190
# 69              0     7.84             1983.956937         98.0         0
#
# ...

# %%
who_df_10.describe()
# Out:
#          Year  Life expectancy   Adult Mortality  infant deaths     Alcohol  \
# count   183.0        183.000000       183.000000     183.000000  182.000000
# mean   2010.0         70.048634       161.863388      27.928962    4.943626
# std       0.0          9.302959       120.435555     104.025305    3.889271
# min    2010.0         36.300000         2.000000       0.000000    0.010000
# 25%    2010.0         63.450000        73.500000       0.000000    1.372500
# 50%    2010.0         72.800000       142.000000       3.000000    4.210000
# 75%    2010.0         75.800000       221.500000      21.000000    7.927500
# max    2010.0         89.000000       682.000000    1200.000000   14.970000
#
#        percentage expenditure  Hepatitis B       Measles         BMI   \
# count              183.000000   168.000000     183.000000  181.000000
# mean               768.221388    80.732143    1878.721311   38.513812
# std               1867.395778    25.628968    9806.616023   21.043111
# ...

# %%
who_df_10.columns = [col.strip() for col in who_df_10.columns] # remove spaces
who_df_10.columns = [col.rstrip() for col in who_df_10.columns]

# %%
who_df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# thinness  1-19 years               float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
# Iterate through columns and print the number of NaN values
for column in who_df_10.columns:
    nan_count = who_df_10[column].isnull().sum()
    print(f"Number of NaN values in '{column}': {nan_count}")
# Out:
# Number of NaN values in 'Country': 0
# Number of NaN values in 'Year': 0
# Number of NaN values in 'Status': 0
# Number of NaN values in 'Life expectancy': 0
# Number of NaN values in 'Adult Mortality': 0
# Number of NaN values in 'infant deaths': 0
# Number of NaN values in 'Alcohol': 1
# Number of NaN values in 'percentage expenditure': 0
# Number of NaN values in 'Hepatitis B': 15
# Number of NaN values in 'Measles': 0
# Number of NaN values in 'BMI': 2
# Number of NaN values in 'under-five deaths': 0
# Number of NaN values in 'Polio': 1
# Number of NaN values in 'Total expenditure': 3
# Number of NaN values in 'Diphtheria': 1
# Number of NaN values in 'HIV/AIDS': 0
# Number of NaN values in 'GDP': 27
# Number of NaN values in 'Population': 40
# Number of NaN values in 'thinness  1-19 years': 2
# Number of NaN values in 'thinness 5-9 years': 2
# Number of NaN values in 'Income composition of resources': 10
# Number of NaN values in 'Schooling': 10

# %%
#rpleace Nan with median

who_df_10["Life expectancy"].fillna(who_df_10["Life expectancy"].median(),inplace=True)
who_df_10["Adult Mortality"].fillna(who_df_10["Adult Mortality"].median(),inplace=True)
who_df_10["Alcohol"].fillna(who_df_10["Alcohol"].median(),inplace=True)
who_df_10["Hepatitis B"].fillna(who_df_10["Hepatitis B"].median(),inplace=True)
who_df_10["BMI"].fillna(who_df_10["BMI"].median(),inplace=True)
who_df_10["Polio"].fillna(who_df_10["Polio"].median(),inplace=True)
who_df_10["Total expenditure"].fillna(who_df_10["Total expenditure"].median(),inplace=True)
who_df_10["Diphtheria"].fillna(who_df_10["Diphtheria"].median(),inplace=True)
who_df_10["Population"].fillna(round(who_df_10["Population"].median(),ndigits=2),inplace=True)
who_df_10["GDP"].fillna(who_df_10["GDP"].median(),inplace=True)
who_df_10["thinness  1-19 years"].fillna(who_df_10["thinness  1-19 years"].median(),inplace=True)
who_df_10["thinness 5-9 years"].fillna(who_df_10["thinness 5-9 years"].median(),inplace=True)
who_df_10["Income composition of resources"].fillna(who_df_10["Income composition of resources"].median(),inplace=True)
who_df_10["Schooling"].fillna(who_df_10["Schooling"].median(),inplace=True)

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(who_df_10,
                         title="Who Dataset",
                         html={'style': {'full_width': True}},
                         sort=None)
                        # Save to file
profile.to_file('who_report.html') #report with replaced NAs
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-01de64e2bc7a> in <cell line: 8>()
#       6                          sort=None)
#       7                         # Save to file
# ----> 8 profile.to_file('who_report.html') #report with replaced NAs
#
# /usr/local/lib/python3.10/dist-packages/typeguard/__init__.py in wrapper(*args, **kwargs)
#    1031         memo = _CallMemo(python_func, _localns, args=args, kwargs=kwargs)
#    1032         check_argument_types(memo)
# -> 1033         retval = func(*args, **kwargs)
#    1034         try:
#    1035             check_return_type(retval, memo)
#
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py in to_file(self, output_file, silent)
#     353                 create_html_assets(self.config, output_file)
#     354
# ...

# %%
#D Dummies for Status #'Developing': 1 / Developed 0
df_cat = pd.get_dummies(who_df_10['Status'], prefix='', prefix_sep='', drop_first=True)
who_df_10 = pd.concat([who_df_10, df_cat], axis=1)
who_df_10.drop('Status', axis=1, inplace=True)

# %%
plt.figure(figsize=(25,8))
sns.heatmap(who_df_10.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
#K testowy
who_df_10['Income composition of resources'] = np.log(who_df_10['Income composition of resources'] + 1)
who_df_10['Schooling'] = np.log(who_df_10['Schooling'] + 1)
who_df_10['BMI'] = np.log(who_df_10['BMI'] + 1)
who_df_10['Developing'] = np.log(who_df_10['Developing'] + 1)
who_df_10['HIV/AIDS'] = np.log(who_df_10['HIV/AIDS'] + 1)
who_df_10['infant deaths'] = np.log(who_df_10['infant deaths'] + 1)
who_df_10['Adult Mortality'] = np.log(who_df_10['Adult Mortality'] + 1)
who_df_10['thinness  1-19 years'] = np.log(who_df_10['thinness  1-19 years'] + 1)

# %%
columns_to_plot = ['Income composition of resources', 'Schooling', 'BMI', 'Developing',
                   'HIV/AIDS', 'infant deaths', 'Adult Mortality', 'thinness  1-19 years']

# %%
who_df_10.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Life expectancy'}>,
#         <Axes: title={'center': 'Adult Mortality'}>,
#         <Axes: title={'center': 'infant deaths'}>,
#         <Axes: title={'center': 'Alcohol'}>],
#        [<Axes: title={'center': 'percentage expenditure'}>,
#         <Axes: title={'center': 'Hepatitis B'}>,
#         <Axes: title={'center': 'Measles'}>,
#         <Axes: title={'center': 'BMI'}>,
#         <Axes: title={'center': 'under-five deaths'}>],
#        [<Axes: title={'center': 'Polio'}>,
#         <Axes: title={'center': 'Total expenditure'}>,
#         <Axes: title={'center': 'Diphtheria'}>,
#         <Axes: title={'center': 'HIV/AIDS'}>,
#         <Axes: title={'center': 'GDP'}>],
#        [<Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'thinness  1-19 years'}>,
#         <Axes: title={'center': 'thinness 5-9 years'}>,
#         <Axes: title={'center': 'Income composition of resources'}>,
# ...

# %%
who_df.Population.value_counts()
# Out:
# 1386542.0     652
# 444.0           4
# 718239.0        2
# 1141.0          2
# 26868.0         2
#              ...
# 4136.0          1
# 482.0           1
# 43.0            1
# 3978.0          1
# 12222251.0      1
# Name: Population, Length: 2279, dtype: int64

# %%
# List of independent variables
independent_variables = ['Income composition of resources', 'Schooling', 'BMI', 'Developing',
                         'HIV/AIDS', 'infant deaths', 'Adult Mortality', 'thinness  1-19 years']

# Create subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(11, 11))

# Iterate through each independent variable
for i, variable in enumerate(independent_variables):
    row, col = divmod(i, 3)  # Calculate the row and column index
    ax = axes[row, col]  # Get the current axis
    ax.scatter(who_df_10[variable], who_df_10['Life expectancy'], alpha=0.5)  # transparency
    ax.set_title(f'Scatter Plot: Life Expectancy vs. {variable}')
    ax.set_xlabel(variable)
    ax.set_ylabel('Life Expectancy')

# Remove any empty subplots
for i in range(len(independent_variables), len(axes.flat)):
    fig.delaxes(axes.flat[i])


# Show the plots
plt.show()
